# %% [markdown]
# Visualize the data using R/Python by plotting the graphs for assignment no. 1 and 2. Consider
# suitable data set. Use Scatter plot, Bar plot, Box plot, Pie chart, Line Chart.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read dataset

df = pd.read_csv('/content/insurance.csv')
print(df.head())
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# Scatter Plot

# %%
plt.figure(figsize=(6, 4))
plt.scatter(df['age'], df['charges'], color='pink', alpha=0.7)
plt.xlabel("Age")
plt.ylabel("BMI")
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# Bar Plot

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x='charges', y='region', data=df, color='pink')
plt.xlabel("Children")
plt.ylabel("Region")
plt.title("Bar Plot")
plt.show()

# %% [markdown]
# Box Plot

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(y=df['bmi'], color='pink')
plt.ylabel("BMI")
plt.title("Box Plot: BMI Distribution")
plt.show()

# %% [markdown]
# Pie Chart

# %%
smoker_counts = df['smoker'].value_counts()
plt.figure(figsize=(6, 4))
plt.pie(smoker_counts, labels=smoker_counts.index, autopct='%1.1f%%', colors=['pink', 'purple'])
plt.title("Pie Chart: Smoker Distribution")
plt.show()

# %% [markdown]
# Line chart

# %%
sorted_data = df.sort_values(by='age')
plt.figure(figsize=(6, 4))
plt.plot(sorted_data['age'], sorted_data['charges'], marker='o', linestyle='-', color='pink')
plt.xlabel("Age")
plt.ylabel("Charges")
plt.title("Line Chart: Age vs Charges")
plt.show()
